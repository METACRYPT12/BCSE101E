# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("D:/BCSE101E/221118/Student_Marks.csv")
print(data.head(10))
sns.boxplot(x=data['Marks'])
# print(data['number_courses'].value_counts())
le = LabelEncoder()
data['number_courses'] = le.fit_transform(data['number_courses'])
data['time_study'] = le.fit_transform(data['time_study'])
print(data.head())
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299
# 5               6       3.211  17.822
# 6               3       6.063  29.889
# 7               5       3.413  17.264
# 8               4       4.410  20.348
# 9               3       6.173  30.862
#    number_courses  time_study   Marks
# 0               0          59  19.202
# 1               1           0   7.734
# 2               1          35  13.811
# 3               3          98  53.018
# 4               5          97  55.299

# %%
fig, ax = plt.subplots(1, 2)
sns.barplot(x=data['number_courses'], y=data['time_study'], ax=ax[0])
sns.barplot(x=data['number_courses'], y=data['Marks'], ax=ax[1])
fig.show()
# Out:
# C:\Users\chait\AppData\Local\Temp\ipykernel_1176\1570427476.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
